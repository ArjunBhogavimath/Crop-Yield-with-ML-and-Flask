# %%
import pandas as pd

# %%
data=pd.read_csv("data/final_crop data.csv")

# %%
data
# Out:
#       Starting month  Cultivation Time  Min-Temp   Max-Temp   \
# 0                  6                 3         24         28
# 1                  6                 3         25         26
# 2                  6                 3         26         31
# 3                  6                 3         24         26
# 4                  6                 3         23         27
# ...              ...               ...        ...        ...
# 1147               6                 4         25         31
# 1148               6                 4         23         30
# 1149               6                 4         24         29
# 1150               6                 4         22         28
# 1151               6                 4         25         32
#
#       Rainfall Requirement  Humidity       Crops  Irrigation      dis  Soil  \
# 0                      956          69      Rice           0    Salem     1
# 1                     1200          85      Rice           0    Salem     1
# ...

# %%
data["Crops"].value_counts()
# Out:
# Jowar        320
# Sugarcane    204
# Cotton       152
# Soyabean     144
# Wheat        129
# Ragi          80
# Rice          72
# Bajra         51
# Name: Crops, dtype: int64

# %%
d={"Jowar":"corn","Bajra":"millet","Sugarcane":"sugarcane","Cotton":"cotton","Soyabean":"soyabean","Wheat":"wheat","Ragi":"ragi","Rice":"rice"}

# %%
data["Crops"]=data["Crops"].map(d)

# %%
data
# Out:
#       Starting month  Cultivation Time  Min-Temp   Max-Temp   \
# 0                  6                 3         24         28
# 1                  6                 3         25         26
# 2                  6                 3         26         31
# 3                  6                 3         24         26
# 4                  6                 3         23         27
# ...              ...               ...        ...        ...
# 1147               6                 4         25         31
# 1148               6                 4         23         30
# 1149               6                 4         24         29
# 1150               6                 4         22         28
# 1151               6                 4         25         32
#
#       Rainfall Requirement  Humidity       Crops  Irrigation      dis  Soil  \
# 0                      956          69      rice           0    Salem     1
# 1                     1200          85      rice           0    Salem     1
# ...

# %%
data["Crops"].value_counts()
# Out:
# corn         320
# sugarcane    204
# cotton       152
# soyabean     144
# wheat        129
# ragi          80
# rice          72
# millet        51
# Name: Crops, dtype: int64

# %%
data.to_csv("data/final_modified_data.csv")

# %%
data["dis"].value_counts()
# Out:
# Madurai       324
# Salem         232
# Coimbatore    220
# Dindigul      216
# Theni         160
# Name: dis, dtype: int64

# %%
data["Soil"].value_counts()
# Out:
# 2    452
# 3    435
# 1    265
# Name: Soil, dtype: int64
